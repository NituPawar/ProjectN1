# %%
print(5*5)
x=2*3
print(x)
# Out:
# 25
# 6

# %%
from pathlib import Path

# Replace 'training_dir' with the actual path to your directory
training_dir = Path('Image_1000_850')

# Use the glob pattern to match TIF files
tif_files = list(training_dir.glob('**/*.tif'))

# Count the number of TIF files
image_count = len(tif_files)

print(image_count)
# Out:
# 20

# %%
class_names = training_dir.class_names
print(class_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class_names = training_dir.class_names
#       2 print(class_names)
#
# AttributeError: 'WindowsPath' object has no attribute 'class_names'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in training_dir.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
  #  plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(10, 10))
# ----> 4 for images, labels in training_dir.take(1):
#       5   for i in range(9):
#       6     ax = plt.subplot(3, 3, i + 1)
#
# AttributeError: 'WindowsPath' object has no attribute 'take'

# %%
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image

# Replace 'training_dir' with the actual path to your directory
training_dir = Path('Image_1000_850')

# Get a list of TIF files in the directory
tif_files = list(training_dir.glob('**/*.tif'))

# Display the first 9 images
plt.figure(figsize=(15, 15))
for i in range(20):
    img_path = tif_files[i]
    img = Image.open(img_path)
    plt.subplot(6, 6, i + 1)
    plt.title(img_path.name)
    plt.imshow(img)
    plt.axis('off')

plt.show()
